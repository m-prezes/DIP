# %%
import pandas as pd
import torch as t

from master_thesis.core.utils.reproducibility import seed_everything
from master_thesis.core.separability.calinski_harabasz_index import (
    CalinskiHarabaszIndex,
)

DEVICE = "cuda"
PROMPT_TYPE = "few_shot"
POSITIVE_TOKEN = "true"
NEGATIVE_TOKEN = "false"
MODEL = "LLAMA_2_7B_CHAT"

DATA_DIR = "../../../../data"
DATASETS_DIR = f"{DATA_DIR}/datasets/base_experiments/car_vs_bike/train"

# %%
seed_everything()

# %% [markdown]
# ### Label aspect

# %%
label_activations_dir = f"{DATA_DIR}/activations/{MODEL}/base_experiments/car_vs_bike/train/few_shot_label_aspect"
label_aspect_df = pd.read_csv(f"{DATASETS_DIR}/label_aspect.csv")

# %%
linear_model_separability = CalinskiHarabaszIndex(
    activations_dir=label_activations_dir,
    dataset=label_aspect_df,
    aspect="label",
    layers=range(1, 32),
)

linear_model_separability.plot_separability_score(
    show=True, save_path=".cache/calinski_harabasz/label_aspect.png"
)
# Out:
# Collecting activations from layer 1:   0%|          | 0/8 [00:00<?, ?it/s]
# Collecting activations from layer 1: 100%|██████████| 8/8 [00:02<00:00,  2.74it/s]
# Collecting activations from layer 2: 100%|██████████| 8/8 [00:00<00:00, 1086.85it/s]
# Collecting activations from layer 3: 100%|██████████| 8/8 [00:00<00:00, 1135.01it/s]
# Collecting activations from layer 4: 100%|██████████| 8/8 [00:00<00:00, 1238.35it/s]
# Collecting activations from layer 5: 100%|██████████| 8/8 [00:00<00:00, 1250.07it/s]
# Collecting activations from layer 6: 100%|██████████| 8/8 [00:00<00:00, 1081.88it/s]
# Collecting activations from layer 7: 100%|██████████| 8/8 [00:00<00:00, 1188.48it/s]
# Collecting activations from layer 8: 100%|██████████| 8/8 [00:00<00:00, 1163.71it/s]
# Collecting activations from layer 9: 100%|██████████| 8/8 [00:00<00:00, 1212.10it/s]
# Collecting activations from layer 10: 100%|██████████| 8/8 [00:00<00:00, 1185.50it/s]
# Collecting activations from layer 11: 100%|██████████| 8/8 [00:00<00:00, 1142.12it/s]
# Collecting activations from layer 12: 100%|██████████| 8/8 [00:00<00:00, 1172.37it/s]
# Collecting activations from layer 13: 100%|██████████| 8/8 [00:00<00:00, 964.04it/s]
# Collecting activations from layer 14: 100%|██████████| 8/8 [00:00<00:00, 1123.91it/s]
# Collecting activations from layer 15: 100%|██████████| 8/8 [00:00<00:00, 1223.27it/s]
# Collecting activations from layer 16: 100%|██████████| 8/8 [00:00<00:00, 1237.67it/s]
# Collecting activations from layer 17: 100%|██████████| 8/8 [00:00<00:00, 1214.77it/s]
# Collecting activations from layer 18: 100%|██████████| 8/8 [00:00<00:00, 1219.63it/s]
# Collecting activations from layer 19: 100%|██████████| 8/8 [00:00<00:00, 1059.20it/s]
# Collecting activations from layer 20: 100%|██████████| 8/8 [00:00<00:00, 1090.00it/s]
# Collecting activations from layer 21: 100%|██████████| 8/8 [00:00<00:00, 1235.62it/s]
# Collecting activations from layer 22: 100%|██████████| 8/8 [00:00<00:00, 1053.51it/s]
# Collecting activations from layer 23: 100%|██████████| 8/8 [00:00<00:00, 858.98it/s]
# Collecting activations from layer 24: 100%|██████████| 8/8 [00:00<00:00, 1238.99it/s]
# Collecting activations from layer 25: 100%|██████████| 8/8 [00:00<00:00, 1171.55it/s]
# Collecting activations from layer 26: 100%|██████████| 8/8 [00:00<00:00, 1165.69it/s]
# Collecting activations from layer 27: 100%|██████████| 8/8 [00:00<00:00, 1189.20it/s]
# Collecting activations from layer 28: 100%|██████████| 8/8 [00:00<00:00, 1177.06it/s]
# Collecting activations from layer 29: 100%|██████████| 8/8 [00:00<00:00, 1236.25it/s]
# Collecting activations from layer 30: 100%|██████████| 8/8 [00:00<00:00, 1203.92it/s]
# Collecting activations from layer 31: 100%|██████████| 8/8 [00:00<00:00, 1123.50it/s]

# %% [markdown]
# ### Confounding aspect

# %%
confounding_activations_dir = f"{DATA_DIR}/activations/{MODEL}/base_experiments/car_vs_bike/train/few_shot_confounding_aspect"
confounding_aspect_df = pd.read_csv(f"{DATASETS_DIR}/confounding_aspect.csv")

# %%
linear_model_separability = CalinskiHarabaszIndex(
    activations_dir=confounding_activations_dir,
    dataset=confounding_aspect_df,
    aspect="confounding",
    layers=range(1, 32),
)

linear_model_separability.plot_separability_score(
    show=True, save_path=".cache/calinski_harabasz/confounding_aspect.png"
)
# Out:
# Collecting activations from layer 1: 100%|██████████| 8/8 [00:00<00:00, 1056.80it/s]
# Collecting activations from layer 2: 100%|██████████| 8/8 [00:00<00:00, 1146.18it/s]
# Collecting activations from layer 3: 100%|██████████| 8/8 [00:00<00:00, 1134.36it/s]
# Collecting activations from layer 4: 100%|██████████| 8/8 [00:00<00:00, 1130.84it/s]
# Collecting activations from layer 5: 100%|██████████| 8/8 [00:00<00:00, 1143.80it/s]
# Collecting activations from layer 6: 100%|██████████| 8/8 [00:00<00:00, 1172.58it/s]
# Collecting activations from layer 7: 100%|██████████| 8/8 [00:00<00:00, 1176.44it/s]
# Collecting activations from layer 8: 100%|██████████| 8/8 [00:00<00:00, 1138.71it/s]
# Collecting activations from layer 9: 100%|██████████| 8/8 [00:00<00:00, 1159.61it/s]
# Collecting activations from layer 10: 100%|██████████| 8/8 [00:00<00:00, 1223.54it/s]
# Collecting activations from layer 11: 100%|██████████| 8/8 [00:00<00:00, 1165.81it/s]
# Collecting activations from layer 12: 100%|██████████| 8/8 [00:00<00:00, 1195.30it/s]
# Collecting activations from layer 13: 100%|██████████| 8/8 [00:00<00:00, 1180.33it/s]
# Collecting activations from layer 14: 100%|██████████| 8/8 [00:00<00:00, 1189.03it/s]
# Collecting activations from layer 15: 100%|██████████| 8/8 [00:00<00:00, 1177.72it/s]
# Collecting activations from layer 16: 100%|██████████| 8/8 [00:00<00:00, 1159.49it/s]
# Collecting activations from layer 17: 100%|██████████| 8/8 [00:00<00:00, 1172.99it/s]
# Collecting activations from layer 18: 100%|██████████| 8/8 [00:00<00:00, 1181.37it/s]
# Collecting activations from layer 19: 100%|██████████| 8/8 [00:00<00:00, 1177.56it/s]
# Collecting activations from layer 20: 100%|██████████| 8/8 [00:00<00:00, 1184.83it/s]
# Collecting activations from layer 21: 100%|██████████| 8/8 [00:00<00:00, 1058.77it/s]
# Collecting activations from layer 22: 100%|██████████| 8/8 [00:00<00:00, 592.20it/s]
# Collecting activations from layer 23: 100%|██████████| 8/8 [00:00<00:00, 1161.86it/s]
# Collecting activations from layer 24: 100%|██████████| 8/8 [00:00<00:00, 1224.21it/s]
# Collecting activations from layer 25: 100%|██████████| 8/8 [00:00<00:00, 1204.31it/s]
# Collecting activations from layer 26: 100%|██████████| 8/8 [00:00<00:00, 1201.55it/s]
# Collecting activations from layer 27: 100%|██████████| 8/8 [00:00<00:00, 1168.66it/s]
# Collecting activations from layer 28: 100%|██████████| 8/8 [00:00<00:00, 1213.89it/s]
# Collecting activations from layer 29: 100%|██████████| 8/8 [00:00<00:00, 1161.66it/s]
# Collecting activations from layer 30: 100%|██████████| 8/8 [00:00<00:00, 1178.34it/s]
# Collecting activations from layer 31: 100%|██████████| 8/8 [00:00<00:00, 1171.31it/s]
